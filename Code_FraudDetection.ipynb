# %%
import pandas as pd
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Identify the values for Class
df["Class"].unique()
# Out:
# array(["'0'", "'1'"], dtype=object)

# %%
# Lets group the numerical values related with the feature: 
df.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# '0'    94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# '1'    80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# '0'    0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# '1'   -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# '0'   -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# '1'    0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# '0'     88.291022
# '1'    122.211321
#
# [2 rows x 30 columns]

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %%
df.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %%
def check_duplicates(df):
    # Check if there are any duplicate rows in the DataFrame
    duplicates = df.duplicated()

    # Return True if duplicates exist, False otherwise
    return duplicates.any()

# Test the function
csv_file = "creditcard.csv"
df = pd.read_csv(csv_file)
result = check_duplicates(df)
print(result)
# Out:
# True

# %%
def get_duplicate_rows(df):
    # Read the dataset into a Pandas DataFrame
    df = pd.read_csv(df)

    # Find duplicate rows in the DataFrame
    duplicate_mask = df.duplicated()

    # Use boolean indexing to get the duplicate rows
    duplicate_rows = df[duplicate_mask]

    return duplicate_rows

# Test the function
csv_file = "creditcard.csv"
duplicate_rows = get_duplicate_rows(csv_file)
print(duplicate_rows)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
def get_total_duplicate_rows(df):
    # Read the dataset into a Pandas DataFrame
    df = pd.read_csv(df)

    # Find duplicate rows in the DataFrame
    duplicate_mask = df.duplicated()

    # Get the total number of duplicated rows
    total_duplicates = duplicate_mask.sum()

    return total_duplicates

# Test the function
csv_file = "creditcard.csv"
total_duplicates = get_total_duplicate_rows(csv_file)
print("Total duplicated rows:", total_duplicates)
# Out:
# Total duplicated rows: 1081

# %%
def remove_duplicates(df):
    # Read the dataset into a Pandas DataFrame
    df = pd.read_csv(df)

    # Remove duplicate rows and keep only the unique rows
    df_unique = df.drop_duplicates()

    return df_unique

# Test the function
csv_file = "creditcard.csv"
unique_rows_df = remove_duplicates(csv_file)
print(unique_rows_df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
unique_rows_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

def remove_duplicates(df):
    # Read the dataset into a Pandas DataFrame
    df = pd.read_csv(df)

    # Remove duplicate rows and keep only the unique rows
    df_unique = df.drop_duplicates()

    return df_unique

# Test the function
csv_file = "creditcard.csv"
unique_rows_df = remove_duplicates(csv_file)

# Suppress warnings related to deprecated distplot
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    
    # Plot the distribution of 'Time' feature using distplot
    plt.figure(figsize=(18, 4))
    sns.distplot(unique_rows_df['Time'].values / (60 * 60), color='r')

    # Plot the distribution of 'Amount' feature using distplot
    plt.figure(figsize=(18, 4))
    sns.distplot(unique_rows_df['Amount'].values, color='b')

plt.show()

# %%
import pandas as pd
df2 = pd.read_csv("CC_FRAUD.csv")
df2.head()
# Out:
#                 DOMAIN STATE  ZIPCODE  TIME1  TIME2  VIS1  VIS2  XRN1  XRN2  \
# 0  CDRZLKAJIJVQHCN.COM    AO      675     12     12     1     0     0     1
# 1          NEKSXUK.NET    KK      680     18     18     1     0     0     0
# 2            XOSOP.COM    UO      432      3      3     1     0     0     1
# 3              TMA.COM    KR      119     23     23     0     0     1     0
# 4          VUHZRNB.COM    PO      614      9      9     0     0     0     1
#
#    XRN3  XRN4  XRN5  VAR1  VAR2    VAR3  VAR4  VAR5  TRN_AMT  TOTAL_TRN_AMT  \
# 0     1     0     1     2     1  16.680    34     0    12.95          12.95
# 1     0     0     1     3     0  37.880    23     0    38.85          38.85
# 2     1     0     1     3     1  -9.080    19     2    38.85          38.85
# 3     0     0     3     0     0  -6.392    18     0    11.01          11.01
# 4     0     0     1     3     0  42.512     7     0    12.95          12.95
#
#   TRN_TYPE
# 0    LEGIT
# 1    LEGIT
# 2    LEGIT
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94682 entries, 0 to 94681
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DOMAIN         94682 non-null  object
#  1   STATE          94682 non-null  object
#  2   ZIPCODE        94682 non-null  int64
#  3   TIME1          94682 non-null  int64
#  4   TIME2          94682 non-null  int64
#  5   VIS1           94682 non-null  int64
#  6   VIS2           94682 non-null  int64
#  7   XRN1           94682 non-null  int64
#  8   XRN2           94682 non-null  int64
#  9   XRN3           94682 non-null  int64
#  10  XRN4           94682 non-null  int64
#  11  XRN5           94682 non-null  int64
#  12  VAR1           94682 non-null  int64
#  13  VAR2           94682 non-null  int64
#  14  VAR3           94682 non-null  float64
#  15  VAR4           94682 non-null  int64
#  16  VAR5           94682 non-null  int64
# ...

# %%
# Identify the values for Type of Development  
df2["TRN_TYPE"].unique()
# Out:
# array(['LEGIT', 'FRAUD'], dtype=object)

# %%
df2.tail()
# Out:
#              DOMAIN STATE  ZIPCODE  TIME1  TIME2  VIS1  VIS2  XRN1  XRN2  \
# 94677     XOSOP.COM    MO      685     11     11     0     0     0     1
# 94678  RONHGNCN.COM    KR      108     16     16     0     0     1     0
# 94679     XOSOP.COM    VO      601     18     18     0     0     1     1
# 94680   VUHZRNB.COM    LO      398     23     23     0     0     0     0
# 94681   VUHZRNB.COM   ROK      655     11     11     0     0     0     0
#
#        XRN3  XRN4  XRN5  VAR1  VAR2    VAR3  VAR4  VAR5  TRN_AMT  \
# 94677     1     0     1     3     0   8.112    15     1    49.95
# 94678     0     1     1     4     0  11.248    10     4    12.95
# 94679     1     0     1     2     0  27.824    23     0    38.85
# 94680     0     0     1     3     0  31.904    20     0    12.95
# 94681     0     0     1     2     0  17.608    20     0    33.03
#
#        TOTAL_TRN_AMT TRN_TYPE
# 94677          49.95    LEGIT
# 94678          12.95    LEGIT
# 94679          38.85    LEGIT
# ...

# %%
df2.describe()
# Out:
#             ZIPCODE         TIME1         TIME2          VIS1          VIS2  \
# count  94682.000000  94682.000000  94682.000000  94682.000000  94682.000000
# mean     454.379470     13.864726     13.875858      0.113306      0.018367
# std      228.279524      5.263233      5.258338      0.316968      0.134274
# min      101.000000      0.000000      0.000000      0.000000      0.000000
# 25%      166.000000     10.000000     11.000000      0.000000      0.000000
# 50%      600.000000     14.000000     14.000000      0.000000      0.000000
# 75%      655.000000     18.000000     18.000000      0.000000      0.000000
# max      694.000000     23.000000     23.000000      1.000000      1.000000
#
#                XRN1          XRN2          XRN3          XRN4          XRN5  \
# count  94682.000000  94682.000000  94682.000000  94682.000000  94682.000000
# mean       0.546989      0.541127      0.401185      0.019888      6.176676
# ...

# %%
df3 = pd.read_csv("credit_card_fraud.csv")
df3.head()
# Out:
#   trans_date_trans_time                   merchant       category     amt  \
# 0   2019-01-01 00:00:44  Heller, Gutmann and Zieme    grocery_pos  107.23
# 1   2019-01-01 00:00:51             Lind-Buckridge  entertainment  220.11
# 2   2019-01-01 00:07:27                  Kiehn Inc    grocery_pos   96.29
# 3   2019-01-01 00:09:03                Beier-Hyatt   shopping_pos    7.77
# 4   2019-01-01 00:21:32                 Bruen-Yost       misc_pos    6.85
#
#                        city state      lat      long  city_pop  \
# 0                    Orient    WA  48.8878 -118.2105       149
# 1                Malad City    ID  42.1808 -112.2620      4154
# 2                   Grenada    CA  41.6125 -122.5258       589
# 3  High Rolls Mountain Park    NM  32.9396 -105.8189       899
# 4                   Freedom    WY  43.0172 -111.0292       471
#
#                                  job         dob  \
# 0  Special educational needs teacher  1978-06-21
# ...

# %%
df3.tail()
# Out:
#        trans_date_trans_time                   merchant        category  \
# 339602   2020-12-31 23:57:56             Schmidt-Larkin            home
# 339603   2020-12-31 23:58:04  Pouros, Walker and Spence       kids_pets
# 339604   2020-12-31 23:59:07            Reilly and Sons  health_fitness
# 339605   2020-12-31 23:59:15                  Rau-Robel       kids_pets
# 339606   2020-12-31 23:59:24            Breitenberg LLC          travel
#
#           amt       city state      lat      long  city_pop  \
# 339602  12.68      Wales    AK  64.7556 -165.6723       145
# 339603  13.02  Greenview    CA  41.5403 -122.9366       308
# 339604  43.77      Luray    MO  40.4931  -91.8912       519
# 339605  86.88    Burbank    WA  46.1966 -118.9017      3684
# 339606   7.99       Mesa    ID  44.6255 -116.4493       129
#
#                              job         dob  \
# 339602  Administrator, education  1939-11-09
# 339603       Call centre manager  1958-09-20
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339607 entries, 0 to 339606
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  339607 non-null  object
#  1   merchant               339607 non-null  object
#  2   category               339607 non-null  object
#  3   amt                    339607 non-null  float64
#  4   city                   339607 non-null  object
#  5   state                  339607 non-null  object
#  6   lat                    339607 non-null  float64
#  7   long                   339607 non-null  float64
#  8   city_pop               339607 non-null  int64
#  9   job                    339607 non-null  object
#  10  dob                    339607 non-null  object
#  11  trans_num              339607 non-null  object
#  12  merch_lat              339607 non-null  float64
#  13  merch_long             339607 non-null  float64
# ...

# %%
df3.describe()
# Out:
#                  amt            lat           long      city_pop  \
# count  339607.000000  339607.000000  339607.000000  3.396070e+05
# mean       70.577984      39.718991    -110.622605  1.071409e+05
# std       161.675242       5.094961      12.651370  2.930299e+05
# min         1.000000      20.027100    -165.672300  4.600000e+01
# 25%         9.600000      36.715400    -120.093600  4.710000e+02
# 50%        46.460000      39.617100    -111.098500  1.645000e+03
# 75%        83.350000      41.710000    -100.621500  3.543900e+04
# max     28948.900000      66.693300     -89.628700  2.383912e+06
#
#            merch_lat     merch_long       is_fraud
# count  339607.000000  339607.000000  339607.000000
# mean       39.718853    -110.622383       0.005247
# std         5.130894      12.663998       0.072248
# min        19.027422    -166.671575       0.000000
# 25%        36.817194    -119.823755       0.000000
# 50%        39.586209    -111.036443       0.000000
# ...

# %%
df4 = pd.read_csv("PS_20174392719_1491204439457_log.csv")
df4.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df4.tail()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 6362615               0
# 6362616               0
# 6362617               0
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df4.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
df5 = pd.read_csv("CBM03.20230807224929.csv")
df5.head()
# Out:
#   STATISTIC                  Statistic Label   TLIST(D1)          Daily  \
# 0  CBM03C01  Debit Card Transactions - Total  2020M03D01  2020 March 01
# 1  CBM03C01  Debit Card Transactions - Total  2020M03D01  2020 March 01
# 2  CBM03C01  Debit Card Transactions - Total  2020M03D02  2020 March 02
# 3  CBM03C01  Debit Card Transactions - Total  2020M03D02  2020 March 02
# 4  CBM03C01  Debit Card Transactions - Total  2020M03D03  2020 March 03
#
#    C03634V04374 Daily and Seven Day Rolling Totals    UNIT      VALUE
# 0            10                        Daily total  Number  3259740.0
# 1            20            Seven day rolling total  Number        NaN
# 2            10                        Daily total  Number  3245856.0
# 3            20            Seven day rolling total  Number        NaN
# 4            10                        Daily total  Number  3392281.0

# %%
df5.tail()
# Out:
#      STATISTIC                                    Statistic Label   TLIST(D1)  \
# 9459  CBM03C14  Debit and Credit Card Volumes - Gross New Spen...  2021M01D30
# 9460  CBM03C14  Debit and Credit Card Volumes - Gross New Spen...  2021M01D31
# 9461  CBM03C14  Debit and Credit Card Volumes - Gross New Spen...  2021M01D31
# 9462  CBM03C14  Debit and Credit Card Volumes - Gross New Spen...  2021M02D01
# 9463  CBM03C14  Debit and Credit Card Volumes - Gross New Spen...  2021M02D01
#
#                  Daily  C03634V04374 Daily and Seven Day Rolling Totals  \
# 9459   2021 January 30            20            Seven day rolling total
# 9460   2021 January 31            10                        Daily total
# 9461   2021 January 31            20            Seven day rolling total
# 9462  2021 February 01            10                        Daily total
# 9463  2021 February 01            20            Seven day rolling total
#
#                UNIT      VALUE
# 9459  Euro Thousand  1339817.0
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9464 entries, 0 to 9463
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   STATISTIC                           9464 non-null   object
#  1   Statistic Label                     9464 non-null   object
#  2   TLIST(D1)                           9464 non-null   object
#  3   Daily                               9464 non-null   object
#  4   C03634V04374                        9464 non-null   int64
#  5   Daily and Seven Day Rolling Totals  9464 non-null   object
#  6   UNIT                                9464 non-null   object
#  7   VALUE                               9380 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 591.6+ KB
